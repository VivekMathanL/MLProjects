# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import math
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("hiring.csv")
df
# Out:
#    experience  test_score  interview_score  salary
# 0           2           8                9   50000
# 1           4           8                6   45000
# 2           5           6                7   60000
# 3           2          10               10   65000
# 4           7           9                6   70000
# 5           3           7               10   62000
# 6          10           6                7   72000
# 7          11           7                8   80000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience','test_score','interview_score']],df.salary)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([3770.97028662, 2286.87877991, 3721.53562977])

# %%
reg.intercept_
# Out:
# -4484.880357612434

# %%
reg.predict([[6,10,10]])
# Out:
# array([78225.08545885])

# %%
reg.predict([[6,10,10]])
# Out:
# array([78225.08545885])

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'experience'}>,
#         <AxesSubplot:title={'center':'test_score'}>],
#        [<AxesSubplot:title={'center':'interview_score'}>,
#         <AxesSubplot:title={'center':'salary'}>]], dtype=object)

# %%
x= sorted(df['experience']) 
y= sorted(df['salary'])
plt.plot(x,y, color= 'BLACK')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('EXPERIENCE VS SALARY COMPARISION')
plt.show()


x= sorted(df['interview_score']) 
y= sorted(df['salary'])
plt.plot(x,y, color= 'BLACK')
plt.xlabel('interview_score')
plt.title('INTERVIEW_SCORE VS SALARY COMPARISION')
plt.ylabel('Salary')


x= sorted(df['test_score']) 
y= sorted(df['salary'])
plt.plot(x,y, color= 'BLACK')
plt.xlabel('test_score')
plt.title('TEST_SCORE VS SALARY COMPARISION')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
mylabels= [str (x) for x in df['salary']]
#print(df['salary'])
plt.pie(df['salary'], labels=mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x224df198>,
# ...
#  [Text(1.0470064422182674, 0.3373092200836584, '50000'),
#   Text(0.6804647334644398, 0.8642729583361781, '45000'),
#   Text(0.01371291949228619, 1.0999145220602364, '60000'),
#   Text(-0.7631371810577963, 0.7922257524766287, '65000'),
#   Text(-1.0992307734334765, -0.04113036271224958, '70000'),
#   Text(-0.7175160975759131, -0.833768942645043, '62000'),
#   Text(0.13677816919205674, -1.091463115470454, '72000'),
#   Text(0.9660437955988919, -0.5260792573223989, '80000')])

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['experience'],y=df['salary'])
# Out:
# <AxesSubplot:xlabel='experience', ylabel='salary'>

# %%
sns.regplot(x=df['experience'],y=df['salary'])
sns. re
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7004\2773905131.py in <module>
#       1 sns.regplot(x=df['experience'],y=df['salary'])
# ----> 2 sns. re
#
# AttributeError: module 'seaborn' has no attribute 're'

# %%
list = []

for i in range(20):
 for j in range(10):
    for k in range(10):
        list.append([i,j,k,reg.predict([[i,j,k]])[0]])
        #print(reg.predict([[i,j,k]]))        
#print(list)

# %%
sumlist= []
for i in list:
    sumlist.append([i[0]+i[1]+i[2], i[3]])


sumx= []
sumy= []

for m in sumlist:
# print(m)
 sumx.append(m[0])
 sumy.append(m[1])
 #sumy= m[1]

sns.scatterplot(x= sumx , y= sumy)
# Out:
# <AxesSubplot:>

# %%
plt.bar(sumx, sumy)
# Out:
# <BarContainer object of 2000 artists>
